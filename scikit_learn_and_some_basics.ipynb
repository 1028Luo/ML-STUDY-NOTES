# %% [markdown]
# <a href="https://colab.research.google.com/github/1028Luo/ML-STUDY-NOTES/blob/main/scikit_learn_and_some_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Code implementation follwing the kaggle ML tutorial
# https://www.kaggle.com/code/dansbecker/your-first-machine-learning-model

# %%
# install and import
import pandas as pd
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
# import data

path = kagglehub.dataset_download("dansbecker/melbourne-housing-snapshot")

print("Path to dataset files:", path)

melb_data = pd.read_csv(f"{path}/melb_data.csv")
melb_data.head()
# Out:
# ...
# 100%|██████████| 451k/451k [00:00<00:00, 61.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/dansbecker/melbourne-housing-snapshot/versions/5
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# ...

# %%
print(melb_data.shape)
melb_data.columns
# Out:
# (13580, 21)
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melb_data.dropna(axis = 0)
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 1        Abbotsford  25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford     5 Charles St      3    h  1465000.0     SP
# 4        Abbotsford      55a Park St      4    h  1600000.0     VB
# 6        Abbotsford     124 Yarra St      3    h  1876000.0      S
# 7        Abbotsford    98 Charles St      2    h  1636000.0      S
# ...             ...              ...    ...  ...        ...    ...
# 12205    Whittlesea    30 Sherwin St      3    h   601000.0      S
# 12206  Williamstown      75 Cecil St      3    h  1050000.0     VB
# 12207  Williamstown    2/29 Dover Rd      1    u   385000.0     SP
# 12209       Windsor  201/152 Peel St      2    u   560000.0     PI
# 12212    Yarraville  54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# ...

# %%
# Format the problem and select features

y = melb_data.Price
melb_features = ['Rooms', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt'] # cannot contain string
X = melb_data[melb_features]
X.describe()
X.head()
# Out:
#    Rooms  Car  Landsize  BuildingArea  YearBuilt
# 0      2  1.0     202.0           NaN        NaN
# 1      2  0.0     156.0          79.0     1900.0
# 2      3  0.0     134.0         150.0     1900.0
# 3      3  1.0      94.0           NaN        NaN
# 4      4  2.0     120.0         142.0     2014.0

# %%
# make a state 1 decision tree and predict

from sklearn.tree import DecisionTreeRegressor
melb_model = DecisionTreeRegressor(random_state=1)
melb_model.fit(X,y)

# make prediction for the first 5 properties
prediction = melb_model.predict(X.head())
print(prediction)
print(X.head())

# validation
from sklearn.metrics import mean_absolute_error
predicted_home_prices = melb_model.predict(X)
mean_absolute_error(y, predicted_home_prices)
# Out:
# [1033333.33333333 1035000.         1465000.          850000.
#  1600000.        ]
#    Rooms  Car  Landsize  BuildingArea  YearBuilt
# 0      2  1.0     202.0           NaN        NaN
# 1      2  0.0     156.0          79.0     1900.0
# 2      3  0.0     134.0         150.0     1900.0
# 3      3  1.0      94.0           NaN        NaN
# 4      4  2.0     120.0         142.0     2014.0
# 59704.15783938978

# %%
# split dataset into train and validation
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
melb_model = DecisionTreeRegressor()
melb_model.fit(train_X, train_y)

val_predictions = melb_model.predict(val_X)
print(mean_absolute_error(val_y,val_predictions))
# Out:
# 408471.371152743

# %%
# tree depth and overfitting
# tree depth too much, each leave contains only a few houses,
# prediction is very accurate for in-sample data,
# but very unreliable for new data, this is overfitting
# underfitting is the contrary

# experimenting with different num of leaves
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  386854
# Max leaf nodes: 50  		 Mean Absolute Error:  336225
# Max leaf nodes: 500  		 Mean Absolute Error:  340177
# Max leaf nodes: 5000  		 Mean Absolute Error:  401794

# %%
# random forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

forest_model = RandomForestRegressor(random_state = 1)
forest_model.fit(train_X, train_y)
melb_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 326561.5262623912

# %%
# regression for continuous features, classification for discrete features
Task Type	Examples	Key Algorithms
Supervised Learning	Regression:
  Classification	Linear Regression, Random Forest, SVM, Neural Networks
Unsupervised Learning	Clustering:
  Anomaly Detection, Dimensionality Reduction	K-Means, PCA, DBSCAN
Reinforcement Learning:
  Game AI, Robotics	Q-Learning, PPO, DQN
Generative Models:
  AI-generated text/images	GANs, VAEs, Transformers
Recommendation Systems:
  Netflix, Amazon Suggestions	Collaborative Filtering, Deep Learning
NLP & Vision:
  Chatbots, Object Detection	BERT, GPT, CNNs, Vision Transformers
